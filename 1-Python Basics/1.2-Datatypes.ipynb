# %%
## Integer Example
age = 34
type(age)
# Out:
# int

# %%
## floating point datatype
height = 6.34
print(height)
print(type(height))
# Out:
# 6.34
# <class 'float'>

# %%
## string datatype example
name = "zugnu"
print(name,type(name))
# Out:
# zugnu <class 'str'>

# %%
## boolean datatype
saruu = True
print(saruu,type(saruu))
# Out:
# True <class 'bool'>

# %%
bool()
# Out:
# False

# %%
a =10
b = 10
type(a==b)
# Out:
# bool

# %%
result = "hello" + str(5)
print(result)
# Out:
# hello5
