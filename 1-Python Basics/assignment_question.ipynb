# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
a = str(input("Enter ayn word"))
print(a)
# Out:
# Hello, World!

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num = int(input("Enter any number: "))
if num > 0 :
    print("This is positive number :", num)
elif num < 0:
    print("This is negative number:", num)
else:
    print("This is zero number")
# Out:
# This is negative number: -2

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
## user from input
num1 = int(input("Enter frist number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

## condition check
if num1 > num2 and num1 > num3:
    print("This is frist number largest: ", num1)
elif num2 > num1 and num2 > num3:
    print("This is second number largest: ", num2)
else:
    print("This is third largest number: ", num3)
# Out:
# This is second number largest:  8

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
num= int(input("Enter any number: "))
fact = 1
for i in range(1, num+1):
    fact = fact * i
print("This number is fact: ",fact)
# Out:
# This number is fact:  24

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
a = 2 
b = 4.5
c = "zaggu"
d = True

print(a, type(a))
print(b, type(b))
print(c, type(c))
print(d, type(d))
# Out:
# 2 <class 'int'>
# 4.5 <class 'float'>
# zaggu <class 'str'>
# True <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a = 10
b = 20
c = a
a = b
b = c

print(a)
print(b)
print(c)
# Out:
# 20
# 10
# 10

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code 
a = 12.2
b = 34
print(int(a) + b)
# Out:
# 46

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
frist_name = "Zugnu"
last_name = "Khatoon"
print(frist_name + last_name)
# Out:
# ZugnuKhatoon

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
x = "Hello"

if isinstance(x, str):
    print("x is a string")
else:
    print("x is not a string")
# Out:
# x is a string

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
num1 = int(input("Enter frist number: "))
num2 = int(input("Enter second number: "))

addition = num1 + num2 
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2

print("Addition: ", addition)
print("Subtraction: ", subtraction)
print("Multiplication: ", multiplication)
print("Division: ", division)
# Out:
# Addition:  5
# Subtraction:  -1
# Multiplication:  6
# Division:  0.6666666666666666

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
a = 3
b = 5
a == b
a < b
a > b
a != b
# Out:
# True

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
X = 10
Y = 20
X == Y and x != Y

X == Y or  x != Y

x = True 
not x
# Out:
# False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
# Taking input from the user
num = int(input("Enter a number: "))

# Calculating square
square = num * num

# Displaying result
print("The square of", num, "is", square)
# Out:
# The square of 4 is 16

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = int(input("Enter any number: "))
if num %2 == 0:
    print("THIS IS EVEN NUMBER: ", num)
else:
    print("THIS IS ODD NUMBER: ", num)
# Out:
# THIS IS EVEN NUMBER:  4

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
# Take input from user
n = int(input("Enter a number: "))

# Calculate sum using formula
sum_n = n * (n + 1) // 2   # // is used for integer division

# Display the result
print("The sum of the first", n, "natural numbers is:", sum_n)
# Out:
# The sum of the first 4 natural numbers is: 10

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
# Input from user
year = int(input("Enter a year: "))

# Check if it's a leap year
if (year % 4 == 0):
    if (year % 100 != 0) or (year % 400 == 0):
        print(year, "is a leap year.")
    else:
        print(year, "is not a leap year.")
else:
    print(year, "is not a leap year.")
# Out:
# 2024 is a leap year.

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
# Input from user
text = input("Enter a string: ")

# Reverse the string using slicing
reversed_text = text[::-1]

# Display the result
print("Reversed string is:",text ,"=", reversed_text)
# Out:
# Reversed string is: zignu = ungiz

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
List = [2, 5, 6, 9, 3, 1]
print(sort.List)
