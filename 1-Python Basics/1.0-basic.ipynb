# %%
## Basic Syntax Rules In Python
## Case sensitivity- python is case sensitivity

name="zugnu"
Name="saruu"

print(name)
print(Name)
# Out:
# zugnu
# saruu

# %%
## Indentation
## Python use indentation to define block of code. Consistent use of spaces (commonly 4 spaces) or a tab is reuired.

age=32
if age > 30:
    print(age)

print(age)
# Out:
# 32
# 32

# %%
## This is singe line comment 
print("Hello World")
# Out:
# Hello World

# %%
## Line Continuation
## Use a backslash (\) to continue a statement to the next line.

total = 1 + 2 + 3 + \
4 + 5 + \
6 + 7 

print(total)
# Out:
# 28

# %%
## Multiple Statements on a single line
x = 1; y = 2; z = x + y
print(z)
# Out:
# 3

# %%
## Understand Semnatics In Python
# variable assignment
age = 20 ##age is an integer
name = "zugnu" ## nmae is a string

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## Type Infefence
variable = 20
print(type(variable))
variable  = "zaguu"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## Code exmaples of indentation
if True:
    print("Cprrect Indentation")
    if False:
        print("This not print")
    print("This will print")
print("Outside this if black")
# Out:
# Cprrect Indentation
# This will print
# Outside this if black
