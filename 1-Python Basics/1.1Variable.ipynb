# %%
## Variable

a = 100

# %%
## Declaring And Assigning Variable

age = 20
height = 4.6
is_student = True
name = "zugnu"

## print the variables

print("age:", age)
print("Height:", height)
print("Name", name)
# Out:
# age: 20
# Height: 4.6
# Name zugnu

# %%
## Naming Conventions
## Variable names should be descriptive
## They must start with a letter or an '_' and contain letter, numbers and underscore
## variable names case sensitve

#valid variable names
first_name = "zugnu"
last_name = "khatoon"

# %%
# Invalid variable
#2age = 20
#frist-name = "zugnu"
#@name = "zugnu"

# %%
## case sensitivity
name = "zugnu"
Name = "zugnu"

name == Name
# Out:
# True

# %%
## Understnading Variable types
## Python is dynamically typed, type of variable is determined at runtime
age = 30 #int
height = 4.6 #float
name = "Zugnu" #str
is_student = True #bool

print(type(is_student))
# Out:
# <class 'bool'>

# %%
# Type checking and Conversion

type(height)
# Out:
# float

# %%
age = 25
print(type(age))

# type conversion
age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
age = '25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
# name = "zugnu"
# int(name)
# print(type(name))

# %%
height = 5.11
type(height)
# Out:
# float

# %%
float(int(height))
# Out:
# 5.0

# %%
## Dynamic Typing
## Python allows the type of a variablr to change as the program executes
var = 10 # int
print(var,type(var))

var = "hello"
print(var,type(var))

var = 5.34
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 5.34 <class 'float'>

# %%
## input
age = int(input("what is the age"))
print(age, type(age))
# Out:
# 34 <class 'int'>

# %%
### Simple calculator
num1 = float(input("Enter frist number: "))
num2 =float(input("Enter second number: "))

sum = num1+num2
defference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum:", sum)
print("defference",defference)
print("product", product)
print("quotient")
# Out:
# Sum: 50.0
# defference 40.0
# product 225.0
# quotient
