# %%
## Creating dictionaries
empty_dict={}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
empty_dict=dict()
empty_dict
# Out:
# {}

# %%
student = {"name":"Zugnu","age":20,"grade":'A++'}
print(student)
print(type(student))
# Out:
# {'name': 'Zugnu', 'age': 20, 'grade': 'A++'}
# <class 'dict'>

# %%
# Single key is always used
student={"name":"Zugnu","age":20,"name":24}
print(student)
# Out:
# {'name': 24, 'age': 20}

# %%
## accessing Dictionary Elements
student={"name":"zugnu","age":20,"grade":'A++'}
print(student)
# Out:
# {'name': 'zugnu', 'age': 20, 'grade': 'A++'}

# %%
## Accessing dictionary elements
print(student['grade'])
print(student['age'])

## Accessing using get() method
print(student.get('grade'))
print(student.get('last_name'))
print(student.get('last_name',"Not Available"))
# Out:
# A++
# 20
# A++
# None
# Not Available

# %%
## Modifying Dicitonary Elements
## Dictionary are mutable,so you can add, update or delete elements
print(student)
# Out:
# {'name': 'zugnu', 'age': 20, 'grade': 'A++'}

# %%
student["age"]=18 ##update value for the key
print(student)
student["address"]="India" ## added a new key and value
print(student)
# Out:
# {'name': 'zugnu', 'age': 18, 'grade': 'A++'}
# {'name': 'zugnu', 'age': 18, 'grade': 'A++', 'address': 'India'}

# %%
del student['grade'] ## delete key and value pair
print(student)
# Out:
# {'name': 'zugnu', 'age': 18, 'address': 'India'}

# %%
## Dictionary methods

keys=student.keys() ## get all the keys
print(keys)
values=student.values() ##get all values
print(values)

items=student.items() ## get all key value pair
print(items)
# Out:
# dict_keys(['name', 'age', 'address'])
# dict_values(['zugnu', 18, 'India'])
# dict_items([('name', 'zugnu'), ('age', 18), ('address', 'India')])

# %%
## Shallow copy
student_copy=student
print(student)
print(student_copy)
# Out:
# {'name': 'Zugnu1', 'age': 18, 'address': 'India'}
# {'name': 'Zugnu1', 'age': 18, 'address': 'India'}

# %%
student["name"]="Zugnu2"
print(student)
print(student)
# Out:
# {'name': 'Zugnu2', 'age': 18, 'address': 'India'}
# {'name': 'Zugnu2', 'age': 18, 'address': 'India'}

# %%
student_copy1=student.copy() ## shallow copy
print(student_copy1)
print(student)
# Out:
# {'name': 'Zugnu2', 'age': 18, 'address': 'India'}
# {'name': 'Zugnu2', 'age': 18, 'address': 'India'}

# %%
student["name"]="Zuguu"
print(student_copy1)
print(student)
# Out:
# {'name': 'Zugnu2', 'age': 18, 'address': 'India'}
# {'name': 'Zuguu', 'age': 18, 'address': 'India'}

# %%
## Iterating Over Dictionaries
## You can use loops to iterate over dictiontries, key, values,or items

# Iterating over keys
for keys in student.keys():
    print(keys)
# Out:
# name
# age
# address

# %%
# Iterating over values
for value in student.values():
    print(value)
# Out:
# Zuguu
# 18
# India

# %%
## Iterate over key value pairs
for key,value in student.items():
    print(f"{key}:{value}")
# Out:
# name:Zuguu
# age:18
# address:India

# %%
## Nested Disctionraes
students={
    "student1":{"name":"Zugnu","age":20},
    "student2":{"name":"Sarfraz","age":19}

}
print(students)
# Out:
# {'student1': {'name': 'Zugnu', 'age': 20}, 'student2': {'name': 'Sarfraz', 'age': 19}}

# %%
students.items()
# Out:
# dict_items([('student1', {'name': 'Zugnu', 'age': 20}), ('student2', {'name': 'Sarfraz', 'age': 19})])

# %%
## Access nested dictionaries elementss
print(students["student2"]["name"])
print(students["student2"]["age"])
# Out:
# Sarfraz
# 19

# %%
## Iterating over nested dictionaries
for student_id,student_info in students.items():
    print(f"{student_id}:{student_info}")
    for key,value in student_info.items():
        print(f"{key}:{value}")
# Out:
# student1:{'name': 'Zugnu', 'age': 20}
# name:Zugnu
# age:20
# student2:{'name': 'Sarfraz', 'age': 19}
# name:Sarfraz
# age:19

# %%
## Dictionary Comphrehansion
squares={x:x**2 for x in range(5)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
## Condition dictionary comprehension
evens={x:x**2 for x in range(10) if x%2==0}
print(evens)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
## Practical Examples

## Use a dictionary to count ha frequency of elements of elements in list

numbers=[1,2,2,3,3,3,4,4,4,4]
frequency={}

for number in numbers:
    if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %%
## Merge 2 dictionaries into one

dict1={"a":1,"b":2}
dict2={"b":3,"c":4}
merged_dict={**dict1,**dict2}
print(merged_dict)
# Out:
# {'a': 1, 'b': 3, 'c': 4}
