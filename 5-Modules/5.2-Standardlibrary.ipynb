# %% [markdown]
# #### Standard Library Overview
#
# ### Python's Standard Library is vast collection of modules and packages that come bundled with Python, Providing a wide range of functionalities out of the box. Here's an overview of some of the most commonly used modules and in the Python Standard Library.

# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math 
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## random

import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 4
# apple

# %%
## File And Directory Access
### getcwd() = jaha code run ho raha hai uska path
import os
print(os.getcwd())
# Out:
# z:\Udemy Final\5-Modules

# %%
### mkdir() = new directory banata hai.
os.mkdir('test_dir')

# %%
# Hight level operations on files and collection of files
### Example: एक file से दूसरी file में data copy करना।
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization
### 👉 APIs और NoSQL databases में JSON format बहुत use होता है, इसलिए ये module बहुत important है।
import json
data={'name':'Zugnu', 'age':21}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Zugnu", "age": 21}
# <class 'str'>
# {'name': 'Zugnu', 'age': 21}
# <class 'dict'>

# %%
## csv (Comma Separated Values)
### 👉 Data analysis और Excel जैसी files से data read/write करने के लिए काम आता है।
import csv
with open('example.csv', mode='w', newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['Zugnu', 21])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Zugnu', '21']

# %%
## datetime
### 👉 Current date/time निकालना और date calculation करना (जैसे +days, -days)।
from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2025-12-06 13:10:39.595766
# 2025-12-05 13:10:39.595766

# %%
## time
### 👉 Execution delay देने के लिए useful है।

import time 
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1755604664.8503137
# 1755604666.8526204

# %%
## Regular expresition
import re

pattern = r'\d+'
text='There are 123 apples and 456 oranges.'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
