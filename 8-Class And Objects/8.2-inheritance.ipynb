# %% [markdown]
# ### Inheritance in Python
#
# #### inheritance is a fundamental concept in Object-Oriented Programming (OOP) that allows a class to inherit attributes and methods from another class. This lesson covers single inharitance and multiple inheritance, demonstrating how to create and use them in Python.

# %%
## Inheritance (Single Inheritance)
## Parent class
class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows=windows
        self.doors=doors
        self.enginetype=enginetype
    def drive(self):
        print("The person will drive the {self.enginetype} car ")

# %%
car1=Car(4,5,"petrol")
car1.drive()
# Out:
# The person will drive the {self.enginetype} car

# %%
class Tesla(Car):
    def __init__(self,windows,doors,enginetype,is_selfdriving):
        super().__init__(windows,doors,enginetype)
        self.is_selfdriving=is_selfdriving

    def selfdriving(self):
        print(f"Tesla supports self driving {self.is_selfdriving}")

# %%
tesla1=Tesla(4,5,"electric",True)
tesla1.selfdriving()
# Out:
# Tesla supports self driving True

# %%
tesla1.drive()
# Out:
# The person will drive the {self.enginetype} car

# %%
### Multiple Inheritance
## when a class inherits from more than one base class.

class Animal:
    def __init__(self,name):
        self.name=name
    
    def speak(self):
        print("Subclass must impliment this method")

## Base class 2
class Pet:
    def __init__(self,owner):
        self.owner = owner

### Derived class
class Dog(Animal, Pet):
    def __init__(self,name,owner):
        Animal.__init__(self,name)
        Pet.__init__(self.owner)

def speak(self):
    return f"{self.name} say  woof"

## Create an object
dog=Dog("Zugnu","Sarfaraz")
print(dog.speak())
print(f"owner:{dog.owner}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 26
#      23     return f"{self.name} say  woof"
#      25 ## Create an object
# ---> 26 dog=Dog("Zugnu","Sarfaraz")
#      27 print(dog.speak())
#      28 print(f"owner:{dog.owner}")
#
# Cell In[20], line 20, in Dog.__init__(self, name, owner)
#      18 def __init__(self,name,owner):
#      19     Animal.__init__(self,name)
# ---> 20     Pet.__init__(self.owner)
#
# AttributeError: 'Dog' object has no attribute 'owner'
